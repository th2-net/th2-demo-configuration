# %% [markdown]
# # Data Services for demo run
# See more examples of using data services on the link: https://github.com/th2-net/th2-data-services-utils/tree/master/examples/notebooks
#
# Data services core lib: https://github.com/th2-net/th2-data-services

# %% [markdown]
# # Summary
#
# ----------------------------------------------
#
# Jupyter notebook for demo run analysis.
#
# ## [1] General statistic
#
# ### [1.1] Number of Test Events within requested time range
#
# ### [1.2] Statistics by event type and execution status
# The table aggregates all event types and shows how many of them and how many of them were failed.
#
#
#
# ## [2] Recons analysis
#
# ### [2.1] Summary table
# The table summarizes the work of the check2-recon th2 component, including the list of executed rules and their statuses.
#
# ### [2.2] Distribution by message type
# This table presents how many messages were processed per each message type.
#
#
#
# ## [3] Script analysis
#
# ### [3.1] Basic statistics by test cases
# Shows how many test cases were failed and passed.
#
# ### [3.2] Detailed test case statistics
# This table shows all test runs, their test cases, statuses and time execution.
#
# ### [3.3] Failed Verifications
# The table shows detailed information on failed verifications, including test event ids, failed tags and test case details.
#
# ### [3.4] Plot all data aggregated by supertype into a single chart with filters
#
# ----------------------------------------------

# %%
from pprint import pprint
from IPython.core.display import display, HTML
from datetime import datetime, timedelta
from th2_data_services.events_tree import EventsTree
from th2_data_services.provider.v5.data_source.http import HTTPProvider5DataSource
from th2_data_services.provider.v5.commands import http
from th2_data_services.filter import Filter
from th2_data_services.provider.v5.events_tree import (
    EventsTreeCollectionProvider5, 
    ParentEventsTreeCollectionProvider5
)
from th2_data_services.data import Data
from th2_data_services_utils import utils as Utils
from pandas import DataFrame, Grouper
import pandas as pd
import pickle

# This settings for increase display jupyter notebook and dataframe table.
display(HTML("<style>.container { width:100% !important; }</style>"))
pd.options.display.max_rows = 1500
pd.set_option('display.expand_frame_repr', False)
pd.set_option('display.max_colwidth', 1000)

# For understand which event type on based name we get from stream.
def get_super_type(record):
    name = record.get("eventName")
    parent_id = record.get("parentEventId")
    super_type = record.get("eventType")
    if super_type == "":
        if "Recon" in name:
            super_type = "Recon Folder"
        else:
            if not parent_id:
                super_type = "Test Run"
            else:
                parent_event = collection.get_event(parent_id)
                if parent_event:
                    parent_super_type = get_super_type(parent_event)
                    if parent_super_type == "Test Run":
                        super_type = "Test Case"
                    elif parent_super_type == "Recon Folder":
                        super_type = "Recon Rule"
                    elif parent_super_type == "Recon Rule":
                        super_type = "Recon Status"
                    elif parent_super_type == "Recon Status":
                        super_type = "Recon Event"

    return super_type

# Base extract (transform function)
# record is required arguments.
def extract_basic(record):
    new_object = {}
    start_time = datetime.fromtimestamp(record.get("startTimestamp", {}).get("epochSecond", 0))
    start_time += timedelta(microseconds=record.get("startTimestamp", {}).get("nano", 0)/1000)
    end_time = datetime.fromtimestamp(record.get("endTimestamp", {}).get("epochSecond", 0))
    end_time += timedelta(microseconds=record.get("endTimestamp", {}).get("nano", 0)/1000)
    new_object.update(
        {
            "super_type": get_super_type(record),
            "start_time": start_time,
            "end_time": end_time,
            "status": "SUCCESSFUL" if record.get("successful") else "FAILED",
            "eventName": record.get("eventName"),
            "eventId": record.get("eventId"),
            "parentEventId": record.get("parentEventId"),
            "body": record.get("body"),
            "attachedMessageIds": record.get("attachedMessageIds")
        }
    )
    if new_object['eventName'] is None:
        pprint(record)
    return new_object
# Out:
# /tmp/ipykernel_92886/560299097.py:2: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ## Start and finish test time setup

# %% [markdown]
# Get start and finish test time automatically

# %%
# with open('start_datetime.pickle', 'rb') as f:
#     START_TIME = pickle.load(f)
# with open('finish_datetime.pickle', 'rb') as f:
#     END_TIME = pickle.load(f)
START_TIME = datetime(2022, 3, 30, 15, 58, 40, 174859)
END_TIME = datetime(2022, 3, 30, 16, 3, 18, 56148)

# %% [markdown]
# Create DataSource and EventsTree objects

# %%
URL = F"http://10.64.66.66:30789"  # Url to th2 rpt-data-provider (th2-kube-demo env)

data_source = HTTPProvider5DataSource(URL)
events: Data = data_source.command(
    http.GetEvents(
        start_timestamp=START_TIME,
        end_timestamp=END_TIME,
        attached_messages=True,
        cache=True,
    )
)
    
collection = EventsTreeCollectionProvider5(events, data_source=data_source)

# %% [markdown]
# # [1] General statistic

# %% [markdown]
# ## [1.1] Number of Events in the tree

# %%
len(collection)
# Out:
# 8610

# %% [markdown]
# ## [1.2] Statistic by all event types
# The table aggregates all event types and shows how many of them and how many of them were failed.

# %%
Utils.aggregate_by_groups(events.map(extract_basic), "super_type", total_row=True)
# Out:
#                          count
# super_type
# Checkpoint               262.0
# Checkpoint for session  2358.0
# Outgoing message         262.0
# Recon Event             1203.0
# Send message            1435.0
# Test Case                100.0
# Test Run                   1.0
# Verification            1154.0
# checkMessages            324.0
# checkSequence            324.0
# checkSequenceRule        324.0
# message                  262.0
# placeOrderFIX            262.0
# preFiltering             324.0
# Total                   8595.0

# %% [markdown]
# # [2] Recons analysis

# %% [markdown]
# ## [2.1] Summary table
# The table summarizes the work of the check2-recon th2 component, including the list of executed rules and their statuses.

# %%
def transform_output(record):
    full_path = collection.get_full_path(record.get("eventId"))
    new_obj = {
        "Recon Root": full_path[0].get("eventName"),
        "Recon Rule" : full_path[1].get("eventName"),
        "Rule Status": full_path[2].get("eventName"),
        "Number of Events": 1,
    }
    return new_obj

data: Data = events\
        .map(extract_basic)\
        .filter(lambda record: record.get("super_type") == "Recon Event")\
        .map(transform_output)\

# Functions from pandas.
df = DataFrame(data).groupby(['Recon Root', "Recon Rule", 'Rule Status']).agg({"Number of Events": "sum"})
df = Utils.append_total_rows(df, {"Number of Events": "sum"})
df
# Out:
#                                                                                                             Number of Events
# Recon Root        Recon Rule                                                                Rule Status
# Recon: Demo_Recon ExecutionReport FIX vs CSV: ['demo-csv'] vs ['demo-conn1', 'demo-conn2']  No match                   587.0
#                                                                                             total                      587.0
#                   FIX vs Dropcopy: ['demo-dc1', 'demo-dc2'] vs ['demo-conn1', 'demo-conn2'] Matched failed              20.0
#                                                                                             Matched passed             385.0
#                                                                                             total                      405.0
#                   Match trades rule: ['demo-conn2'] vs ['demo-conn1']                       Matched failed              20.0
#                                                                                             Matched passed             142.0
#                                                                                             No match                     3.0
#                                                                                             total                      165.0
#                   NewOrderSingle FIX vs CSV: ['demo-conn1', 'demo-conn2'] vs ['demo-csv']   No match                    46.0
#                                                                                             total                       46.0

# %% [markdown]
# ## [2.2] Distribution by message type
# This table presents how many messages were processed per each message type.

# %%
def is_recon_ancestor(record):
    parent_id = record.get("parentEventId")
    if parent_id is not None:
        ancestor = collection.find_ancestor(record.get("eventId"), lambda record: get_super_type(record) == "Recon Folder")
        if ancestor:
            return True
    return False

def is_match_or_match_failed(record):
    ancestor = collection.find_ancestor(record.get("eventId"), lambda record: record.get("eventName") == "No match")
    if ancestor and not ancestor.get("successful"):
        return True
    ancestor = collection.find_ancestor(record.get("eventId"), lambda record: record.get("eventName") == "Matched passed")
    if ancestor:
        return True
    return False

def exctract_block(record):
    messages_id = record.get("attachedMessageIds")
    
    if not messages_id:
        return None
    
    messages = data_source.command(http.GetMessagesById(messages_id))
    output = [{"MsgType": message.get("body", {}).get("metadata", {}).get("messageType")} for message in messages]
    ## [2.2] Distribution by message type
    ## This table presents how many messages were processed per each message type.
    return output

data = events\
        .map(extract_basic)\
        .filter(is_recon_ancestor)\
        .filter(is_match_or_match_failed)\
        .map(exctract_block)

df = DataFrame(data)
df.groupby("MsgType").size().reset_index(name="count")
# Out:
#            MsgType  count
# 0  ExecutionReport   1642
# 1   NewOrderSingle     46

# %% [markdown]
# # [3] Script analysis

# %% [markdown]
# ## [3.1] Basic statistics by test cases
# Shows how many test cases were failed and passed.

# %%
def transform_output(record):    
    new_obj = {
        "Test Case": 1,
        "Status": record.get("status")
    }
    return new_obj

data = events\
        .map(extract_basic)\
        .filter(lambda record: record.get("super_type") == "Test Case")\
        .map(transform_output)

df = DataFrame(data=data)
df = df.groupby(["Status"]).sum()
df["Percent"] = df["Test Case"] / df["Test Case"].sum() * 100
df
# Out:
#             Test Case  Percent
# Status
# FAILED             59     59.0
# SUCCESSFUL         41     41.0

# %% [markdown]
# ## [3.2] Detailed test case statistics
# This table shows all test runs, their test cases, statuses and time execution.

# %%
def ancestor_is_test_case(record):
    if not record.get("parentEventId"):
        return False
    ancestor = collection.find_ancestor(record.get("eventId"), lambda record: get_super_type(record) == "Test Case")
    if ancestor:
        return True
    return False

def transform_output(record):
    fullpath = collection.get_full_path(record.get("eventId"))
    
    start_time = datetime.fromtimestamp(fullpath[1].get("startTimestamp", {}).get("epochSecond", 0))
    start_time += timedelta(microseconds=fullpath[1].get("startTimestamp", {}).get("nano", 0)/1000)
    
    message_id = record.get("attachedMessageIds")
    if not message_id:
        return None
    message_id = message_id[0]
    
    message = data_source.command(http.GetMessageById(message_id))
    if not message:
        return None
    
    body = message.get("body", {})
    if not body:
        return None
    
    end_time = body.get("metadata", {}).get("timestamp")
    end_time = datetime.strptime(end_time, "%Y-%m-%dT%H:%M:%S.%fZ")
    end_time += timedelta(hours=3)
    
    new_obj = {
        "Test Run": fullpath[0].get("eventName"),
        "Test Case": fullpath[1].get("eventName"),
        "Status": "SUCCESSFUL" if fullpath[1].get("successful") else "FAILED",
        'Start Time': start_time,
        'End Time': end_time,
    }
    return new_obj

data = events\
        .map(extract_basic)\
        .filter(ancestor_is_test_case)\
        .filter(lambda record: record.get("super_type") in ["Verification", "message"])\
        .map(transform_output)

df = DataFrame(data=data)
df = df.groupby(["Test Run", "Test Case", "Status"]).agg({"Start Time": "min", "End Time": "max"}).reset_index()
df["duration"] = df["End Time"] - df["Start Time"]
df.sort_values(by=["Start Time"])
# Out:
#                                                                         Test Run                                                                     Test Case      Status                 Start Time                End Time               duration
# 11  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first    Case[TC_1.1]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR1  SUCCESSFUL 2022-03-30 19:58:40.490038 2022-03-30 19:58:43.797 0 days 00:00:03.306962
# 22  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first    Case[TC_1.2]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR5      FAILED 2022-03-30 19:58:44.285127 2022-03-30 19:58:46.735 0 days 00:00:02.449873
# 33  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first    Case[TC_1.3]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR6      FAILED 2022-03-30 19:58:47.122339 2022-03-30 19:58:47.453 0 days 00:00:00.330661
# 44  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first    Case[TC_1.4]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR6      FAILED 2022-03-30 19:58:47.808835 2022-03-30 19:58:48.441 0 days 00:00:00.632165
# 55  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first    Case[TC_1.5]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR6      FAILED 2022-03-30 19:58:48.816254 2022-03-30 19:58:49.425 0 days 00:00:00.608746
# 66  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first    Case[TC_1.6]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR4      FAILED 2022-03-30 19:58:49.779089 2022-03-30 19:58:52.683 0 days 00:00:02.903911
# 77  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first    Case[TC_1.7]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR4      FAILED 2022-03-30 19:58:53.094320 2022-03-30 19:58:55.713 0 days 00:00:02.618680
# 88  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first    Case[TC_1.8]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR4      FAILED 2022-03-30 19:58:56.161442 2022-03-30 19:58:58.639 0 days 00:00:02.477558
# 99  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first    Case[TC_1.9]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR5      FAILED 2022-03-30 19:58:59.092708 2022-03-30 19:59:01.677 0 days 00:00:02.584292
# 1   [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first   Case[TC_1.10]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR3  SUCCESSFUL 2022-03-30 19:59:02.072827 2022-03-30 19:59:04.677 0 days 00:00:02.604173
# 2   [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first   Case[TC_1.11]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR2  SUCCESSFUL 2022-03-30 19:59:05.055486 2022-03-30 19:59:07.630 0 days 00:00:02.574514
# 3   [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first   Case[TC_1.12]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR4      FAILED 2022-03-30 19:59:08.080701 2022-03-30 19:59:10.638 0 days 00:00:02.557299
# 4   [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first   Case[TC_1.13]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR6      FAILED 2022-03-30 19:59:11.079683 2022-03-30 19:59:11.402 0 days 00:00:00.322317
# 5   [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first   Case[TC_1.14]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR6      FAILED 2022-03-30 19:59:11.760039 2022-03-30 19:59:12.399 0 days 00:00:00.638961
# 6   [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first   Case[TC_1.15]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR4      FAILED 2022-03-30 19:59:12.773109 2022-03-30 19:59:15.639 0 days 00:00:02.865891
# 7   [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first   Case[TC_1.16]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR4      FAILED 2022-03-30 19:59:16.052441 2022-03-30 19:59:18.644 0 days 00:00:02.591559
# 8   [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first   Case[TC_1.17]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR2  SUCCESSFUL 2022-03-30 19:59:19.056603 2022-03-30 19:59:21.633 0 days 00:00:02.576397
# 9   [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first   Case[TC_1.18]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR4      FAILED 2022-03-30 19:59:22.069373 2022-03-30 19:59:24.632 0 days 00:00:02.562627
# 10  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first   Case[TC_1.19]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR1  SUCCESSFUL 2022-03-30 19:59:25.044246 2022-03-30 19:59:27.639 0 days 00:00:02.594754
# 12  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first   Case[TC_1
: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR3  SUCCESSFUL 2022-03-30 20:02:40.030006 2022-03-30 20:02:42.637 0 days 00:00:02.606994
# 91  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first   Case[TC_1.92]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR2  SUCCESSFUL 2022-03-30 20:02:43.047156 2022-03-30 20:02:45.633 0 days 00:00:02.585844
# 92  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first   Case[TC_1.93]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR5      FAILED 2022-03-30 20:02:46.058228 2022-03-30 20:02:48.634 0 days 00:00:02.575772
# 93  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first   Case[TC_1.94]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR6      FAILED 2022-03-30 20:02:49.138404 2022-03-30 20:02:49.392 0 days 00:00:00.253596
# 94  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first   Case[TC_1.95]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR4      FAILED 2022-03-30 20:02:49.727853 2022-03-30 20:02:52.646 0 days 00:00:02.918147
# 95  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first   Case[TC_1.96]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR3  SUCCESSFUL 2022-03-30 20:02:53.044017 2022-03-30 20:02:55.634 0 days 00:00:02.589983
# 96  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first   Case[TC_1.97]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR3  SUCCESSFUL 2022-03-30 20:02:56.039811 2022-03-30 20:02:58.625 0 days 00:00:02.585189
# 97  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first   Case[TC_1.98]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR2  SUCCESSFUL 2022-03-30 20:02:59.043430 2022-03-30 20:03:01.632 0 days 00:00:02.588570
# 98  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first   Case[TC_1.99]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR5      FAILED 2022-03-30 20:03:02.054172 2022-03-30 20:03:04.623 0 days 00:00:02.568828
# 0   [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first  Case[TC_1.100]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR1  SUCCESSFUL 2022-03-30 20:03:05.063303 2022-03-30 20:03:07.619 0 days 00:00:02.555697

# %% [markdown]
# ## [3.3] Failed Verifications
# The table shows detailed information on failed verifications, including test event ids, failed tags and test case details.

# %%
def is_test_case_ancestor(record):
    parent_id = record.get("parentEventId")
    if parent_id is not None:
        ancestor = collection.find_ancestor(record.get("eventId"), lambda record: get_super_type(record) == "Test Case")
        if ancestor:
            return True
    return False

def extract_failed_tags(record):
    new_obj = {
        "Event Id": record.get("eventId"),
        "Event Name": record.get("eventName"),
        "Test Run": collection.find_ancestor(record.get("eventId"), lambda record: get_super_type(record) == "Test Run").get("eventName"),
        "Test Case": collection.find_ancestor(record.get("eventId"), lambda record: get_super_type(record) == "Test Case").get("eventName"),
    }
    for content in record.get("body"):
        tags = Utils.search_fields(content, "OrderCapacity", "AccountType")
    new_obj.update({"tags": tags})
    return new_obj

data = events\
        .map(extract_basic)\
        .filter(is_test_case_ancestor)\
        .filter(lambda record: record.get("super_type") == "Verification")\
        .filter(lambda record: record.get("status") == "FAILED")\
        .map(extract_failed_tags)

transform_data = []
for i in data:
    common = {
        "Event Name": i.get("Event Name"),
        "Test Run": i.get("Test Run"),
        "Test Case": i.get("Test Case"),
        "Event_Id": i.get("Event Id"),
    }
    for tag, payload in i["tags"].items():
        for value in payload:
            if value.get("status") == "FAILED":
                transform_data.append({
                    **common, 
                    "failed_tag": tag, 
                    "failed_actual": value.get("actual"),
                    "failed_expected": value.get("expected"),
                    "failed_operation": value.get("operation")
                })

# From pandas for comforted view
failed_verifications = DataFrame(data=transform_data)
failed_verifications
# Out:
#                                 Event Name                                                                      Test Run                                                                    Test Case                                                                   Event_Id     failed_tag failed_actual failed_expected failed_operation
# 0   Verification 'ExecutionReport' message  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first   Case[TC_1.2]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR5  966e811b-e15f-4f0d-8f4a-1a5d358fda53:485f556d-b042-11ec-926d-addc09e3ba3c  OrderCapacity             P               A            EQUAL
# 1   Verification 'ExecutionReport' message  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first   Case[TC_1.2]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR5  966e811b-e15f-4f0d-8f4a-1a5d358fda53:485f556d-b042-11ec-926d-addc09e3ba3c    AccountType             2               1            EQUAL
# 2   Verification 'ExecutionReport' message  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first   Case[TC_1.9]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR5  ada86c9d-3501-4b4b-9691-f45c2c4d2a94:514ddd23-b042-11ec-926d-addc09e3ba3c  OrderCapacity             P               A            EQUAL
# 3   Verification 'ExecutionReport' message  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first   Case[TC_1.9]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR5  ada86c9d-3501-4b4b-9691-f45c2c4d2a94:514ddd23-b042-11ec-926d-addc09e3ba3c    AccountType             2               1            EQUAL
# 4   Verification 'ExecutionReport' message  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first  Case[TC_1.21]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR5  51e8c693-62ec-4812-8504-467e0ec90f27:66c5c5d3-b042-11ec-926d-addc09e3ba3c  OrderCapacity             P               A            EQUAL
# 5   Verification 'ExecutionReport' message  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first  Case[TC_1.21]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR5  51e8c693-62ec-4812-8504-467e0ec90f27:66c5c5d3-b042-11ec-926d-addc09e3ba3c    AccountType             2               1            EQUAL
# 6   Verification 'ExecutionReport' message  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first  Case[TC_1.28]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR5  0e789b62-6abc-4974-a106-b060131f9d46:7348705e-b042-11ec-926d-addc09e3ba3c  OrderCapacity             P               A            EQUAL
# 7   Verification 'ExecutionReport' message  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first  Case[TC_1.28]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR5  0e789b62-6abc-4974-a106-b060131f9d46:7348705e-b042-11ec-926d-addc09e3ba3c    AccountType             2               1            EQUAL
# 8   Verification 'ExecutionReport' message  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first  Case[TC_1.29]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR5  dd1c73ff-8a07-4b4a-bbd1-adacc808c834:7515686d-b042-11ec-926d-addc09e3ba3c  OrderCapacity             P               A            EQUAL
# 9   Verification 'ExecutionReport' message  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first  Case[TC_1.29]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR5  dd1c73ff-8a07-4b4a-bbd1-adacc808c834:7515686d-b042-11ec-926d-addc09e3ba3c    AccountType             2               1            EQUAL
# 10  Verification 'ExecutionReport' message  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first  Case[TC_1.30]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR5  72585a92-3e3d-498a-9219-60a7d3c56cb4:76d911ac-b042-11ec-926d-addc09e3ba3c  OrderCapacity             P               A            EQUAL
# 11  Verification 'ExecutionReport' message  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first  Case[TC_1.30]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR5  72585a92-3e3d-498a-9219-60a7d3c56cb4:76d911ac-b042-11ec-926d-addc09e3ba3c    AccountType             2               1            EQUAL
# 12  Verification 'ExecutionReport' message  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first  Case[TC_1.39]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR5  8ebf2fd0-5d6e-4b0f-9740-78d799f9bb39:80ff561f-b042-11ec-926d-addc09e3ba3c  OrderCapacity             P               A            EQUAL
# 13  Verification 'ExecutionReport' message  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first  Case[TC_1.39]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR5  8ebf2fd0-5d6e-4b0f-9740-78d799f9bb39:80ff561f-b042-11ec-926d-addc09e3ba3c    AccountType             2               1            EQUAL
# 14  Verification 'ExecutionReport' message  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first  Case[TC_1.43]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR5  9fe9dd0c-f683-41b3-b07d-f399de79792e:8789aeb3-b042-11ec-926d-addc09e3ba3c  OrderCapacity             P               A            EQUAL
# 15  Verification 'ExecutionReport' message  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first  Case[TC_1.43]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR5  9fe9dd0c-f683-41b3-b07d-f399de79792e:8789aeb3-b042-11ec-926d-addc09e3ba3c    AccountType             2               1            EQUAL
# 16  Verification 'ExecutionReport' message  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first  Case[TC_1.44]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR5  0d9f1713-a099-4675-bb1d-422e0717a8da:8954d207-b042-11ec-926d-addc09e3ba3c  OrderCapacity             P               A            EQUAL
# 17  Verification 'ExecutionReport' message  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first  Case[TC_1.44]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR5  0d9f1713-a099-4675-bb1d-422e0717a8da:8954d207-b042-11ec-926d-addc09e3ba3c    AccountType             2               1            EQUAL
# 18  Verification 'ExecutionReport' message  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first  Case[TC_1.49]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR5  750880c8-c990-48ff-b257-0888c67fafd4:9252c223-b042-11ec-926d-addc09e3ba3c  OrderCapacity             P               A            EQUAL
# 19  Verification 'ExecutionReport' message  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first  Case[TC_1.49]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR5  750880c8-c990-48ff-b257-0888c67fafd4:9252c223-b042-11ec-926d-addc09e3ba3c    AccountType             2               1            EQUAL
# 20  Verification 'ExecutionReport' message  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first  Case[TC_1.54]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR5  bd6f6045-5955-4618-8df4-72a143699165:98d26c66-b042-11ec-926d-addc09e3ba3c  OrderCapacity             P               A            EQUAL
# 21  Verification 'ExecutionReport' message  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first  Case[TC_1.54]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR5  bd6f6045-5955-4618-8df4-72a143699165:98d26c66-b042-11ec-926d-addc09e3ba3c    AccountType             2               1            EQUAL
# 22  Verification 'ExecutionReport' message  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first  Case[TC_1.65]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR5  b8b7ecd6-7eed-482b-976b-d36cd4fd323f:a8ebf9b1-b042-11ec-926d-addc09e3ba3c  OrderCapacity             P               A            EQUAL
# 23  Verification 'ExecutionReport' message  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first  Case[TC_1.65]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR5  b8b7ecd6-7eed-482b-976b-d36cd4fd323f:a8ebf9b1-b042-11ec-926d-addc09e3ba3c    AccountType             2               1            EQUAL
# 24  Verification 'ExecutionReport' message  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first  Case[TC_1.72]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR5  7fdda546-a068-4e5d-9d5c-a917d5ceaf8f:b572c3ec-b042-11ec-926d-addc09e3ba3c  OrderCapacity             P               A            EQUAL
# 25  Verification 'ExecutionReport' message  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first  Case[TC_1.72]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR5  7fdda546-a068-4e5d-9d5c-a917d5ceaf8f:b572c3ec-b042-11ec-926d-addc09e3ba3c    AccountType             2               1            EQUAL
# 26  Verification 'ExecutionReport' message  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first  Case[TC_1.73]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR5  a1daec80-7738-44ce-b38b-a4e4300576f3:b73b271b-b042-11ec-926d-addc09e3ba3c  OrderCapacity             P               A            EQUAL
# 27  Verification 'ExecutionReport' message  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first  Case[TC_1.73]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR5  a1daec80-7738-44ce-b38b-a4e4300576f3:b73b271b-b042-11ec-926d-addc09e3ba3c    AccountType             2               1            EQUAL
# 28  Verification 'ExecutionReport' message  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first  Case[TC_1.78]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR5  7a0d867b-e7f4-4925-affd-f7dec744727b:bdc7cab0-b042-11ec-926d-addc09e3ba3c  OrderCapacity             P               A            EQUAL
# 29  Verification 'ExecutionReport' message  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first  Case[TC_1.78]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR5  7a0d867b-e7f4-4925-affd-f7dec744727b:bdc7cab0-b042-11ec-926d-addc09e3ba3c    AccountType             2               1            EQUAL
# 30  Verification 'ExecutionReport' message  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first  Case[TC_1.82]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR5  0cf648d7-03f2-4566-bc26-714d044c23ef:c4f2a938-b042-11ec-926d-addc09e3ba3c  OrderCapacity             P               A            EQUAL
# 31  Verification 'ExecutionReport' message  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first  Case[TC_1.82]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR5  0cf648d7-03f2-4566-bc26-714d044c23ef:c4f2a938-b042-11ec-926d-addc09e3ba3c    AccountType             2               1            EQUAL
# 32  Verification 'ExecutionReport' message  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first  Case[TC_1.85]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR5  b6467bc4-a5e7-413b-95c8-51554790d830:ca4da98b-b042-11ec-926d-addc09e3ba3c  OrderCapacity             P               A            EQUAL
# 33  Verification 'ExecutionReport' message  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first  Case[TC_1.85]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR5  b6467bc4-a5e7-413b-95c8-51554790d830:ca4da98b-b042-11ec-926d-addc09e3ba3c    AccountType             2               1            EQUAL
# 34  Verification 'ExecutionReport' message  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first  Case[TC_1.88]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR5  17422531-8c98-4fc3-a988-a811e23b3ea8:cfaaa5a8-b042-11ec-926d-addc09e3ba3c  OrderCapacity             P               A            EQUAL
# 35  Verification 'ExecutionReport' message  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first  Case[TC_1.88]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR5  17422531-8c98-4fc3-a988-a811e23b3ea8:cfaaa5a8-b042-11ec-926d-addc09e3ba3c    AccountType             2               1            EQUAL
# 36  Verification 'ExecutionReport' message  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first  Case[TC_1.93]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR5  9bc5d777-c5c2-45f7-a69b-0157bafa0314:d8a7d373-b042-11ec-926d-addc09e3ba3c  OrderCapacity             P               A            EQUAL
# 37  Verification 'ExecutionReport' message  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first  Case[TC_1.93]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR5  9bc5d777-c5c2-45f7-a69b-0157bafa0314:d8a7d373-b042-11ec-926d-addc09e3ba3c    AccountType             2               1            EQUAL
# 38  Verification 'ExecutionReport' message  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first  Case[TC_1.99]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR5  0ca2d04b-cfa8-421a-ad5d-df95b3dbf4cd:e226664a-b042-11ec-926d-addc09e3ba3c  OrderCapacity             P               A            EQUAL
# 39  Verification 'ExecutionReport' message  [TS_1]Aggressive IOC vs two orders: second order's price is more favorable than first  Case[TC_1.99]: Trader DEMO-CONN1 vs trader DEMO-CONN2 for instrument INSTR5  0ca2d04b-cfa8-421a-ad5d-df95b3dbf4cd:e226664a-b042-11ec-926d-addc09e3ba3c    AccountType             2               1            EQUAL

# %% [markdown]
# ## [3.4] Plot all data aggregated by supertype into a single chart with filters

# %%
def transform_output(record):
    new_obj = {
        "time": record.get("start_time"),
        "super_type": record.get("super_type"),
        "status": record.get("status"),
    }
    return new_obj

data = events\
         .map(extract_basic)\
         .filter(lambda record: record.get("super_type") in ["Recon Event", "Verification"])\
         .map(transform_output)

df = Utils.aggregate_groups_by_intervals(data, "time", "super_type", intervals="10s", pivot="super_type")
Utils.create_tick_diagram(df)  # The plot may not be shown if you have not restarted the notebook.

# %% [markdown]
# ## [3.5] Latency density
# Searches pairs messages with type NewOrderSingle and ExecutionReport. Then calculates latency and demonstrates on plot.

# %%
def is_new_single_order_or_execution_report(record):
    body = record.get("body")
    if body:
        message_type = body.get("metadata", {}).get("messageType")
        if message_type in ["NewOrderSingle", "ExecutionReport"]:
            return True
    return False

def clear_unnecessery_fields(record):
    new_obj = None
    body = record.get("body")
    if body:
        fields = body.get("fields", {})
        clOrdID = fields.get("ClOrdID", {}).get("simpleValue")
        ord_status = fields.get("OrdStatus", {}).get("simpleValue")
        
        metadata = body.get("metadata", {})
        message_type = metadata.get("messageType")
        session_alias = metadata.get("id", {}).get("connectionId", {}).get("sessionAlias")
        time = metadata.get("timestamp")
        
        new_obj = {
            "clOrdID": clOrdID,
            "OrdStatus": ord_status,
            "MessageType": message_type,
            "sessionAlias": session_alias,
            "time": time,
        }
    return new_obj

streams = set()
for record in collection.get_all_events_iter():
    messages = record.get("attachedMessageIds")
    for msg in messages:
        streams.add(msg.split(":")[0])
        
messages = data_source.command(
    http.GetMessages(
        start_timestamp=START_TIME,
        end_timestamp=END_TIME,
        stream=list(streams)
    )
)

data = messages\
        .filter(is_new_single_order_or_execution_report)\
        .map(clear_unnecessery_fields)

roundtrips = {}
latency = []

for record in data:
    msg_type = record.get("MessageType")
    clOrdID = record.get("clOrdID")
    
    if msg_type == "NewOrderSingle":
        if clOrdID not in roundtrips:
            roundtrips[clOrdID] = record.get("time")
    elif msg_type == "ExecutionReport":
        if record.get("OrdStatus") == '0':
            if clOrdID in roundtrips:
                current_latency = datetime.strptime(record.get("time"), "%Y-%m-%dT%H:%M:%S.%fZ") -  datetime.strptime(roundtrips[clOrdID], "%Y-%m-%dT%H:%M:%S.%fZ")
                latency.append({"latency": 1, "time": datetime.strptime(str(current_latency), "%H:%M:%S.%f")})

df = DataFrame(data=latency).set_index("time").groupby(Grouper(freq="10ms")).sum()
df.index = df.index.strftime("%S.%f")

Utils.create_tick_diagram(df)  # The plot may not be shown if you have not restarted the notebook.
